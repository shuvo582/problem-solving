# %% [markdown]
# # Find all the divisors of n

# %%
n = int(input())
for i in range(1,n+1):
    if n % i == 0 :
        print(i)
# Out:
#  6
# 1
# 2
# 3
# 6

# %% [markdown]
# # Here is the most efficient way

# %% [raw]
# The best algorithm for finding all divisors of \( n \) efficiently leverages the fact that divisors come in pairs. Here's a high-level overview:
#
# ### Steps:
# 1. **Iterate up to the square root of \( n \):**
#    To find all divisors, iterate \( i \) from \( 1 \) to \( \sqrt{n} \). For each \( i \):
#    - If \( n \mod i = 0 \), then \( i \) is a divisor.
#    - The corresponding paired divisor is \( n / i \).
#
# 2. **Avoid duplicates for perfect squares:**
#    If \( i \times i = n \), only add \( i \) once to the divisor list to avoid duplication.
#
# 3. **Time complexity:**
#    The algorithm runs in \( O(\sqrt{n}) \), which is much faster than iterating up to \( n \) directly.
#
# This approach minimizes the number of iterations while ensuring all divisors are found. It is optimal for scenarios where \( n \) is large.
#  \) is large.
#  \) is large.

# %% [markdown]
# ![Divisors Image](C:\\Users\\Shuvo\\Pictures\\Saved Pictures\\divisors_n.png)

# %% [markdown]
# ![Divisors Image]("C:\Users\Shuvo\Pictures\Saved Pictures\divisors_n.png")

# %% [markdown]
# ![Divisors Image](r"C:\Users\Shuvo\Pictures\Saved Pictures\divisors_n.png")

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r'C:\Users\Shuvo\Pictures\Saved Pictures\divisors_n.png')
imgplot = plt.imshow(img)
plt.axis('off')  # Hide axes for a cleaner display
plt.show()

# %%
def solveMeFirst(a,b):
    a=int(input())
    b=int(input())
    return a + b

# %%
A= input()
B = input()
count=0
for i in B:
    if i in A:
        count=count+1
if count == len(B):
    print("Yes")
else:
    print("No")
# Out:
#  listen
#  silent
# Yes

# %%
def Arpa(n):
    if n == 0 :
        return 1 
    else:
    	last_digits=[6,8,4,2]
    	return last_digits[n % 4]
	
n=int(input())
print(Arpa(n))
# Out:
#  0
# 1
